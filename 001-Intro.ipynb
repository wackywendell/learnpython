# %% [markdown]
# # Learn to Code

# %% [markdown]
# ### Goals
#
#  * Learn the basics of programming
#  * Learn to import, manipulate, and plot data

# %% [markdown]
# ### Why Python?
#
#  * Easy to learn and use
#  * Relatively simple
#  * Good for data analysis and plotting
#  * Good for machine learning, web development, scripting, text parsing, and many things.

# %% [markdown]
# ## Installing Python
#
# [Install Anaconda](http://continuum.io/downloads#py34), and **get the Python 3 version!**
#
# ### http://continuum.io/downloads#py34

# %% [markdown]
# ## Let's install it now.

# %% [markdown]
# # Let's try it!
#
# 1. Open the Terminal
# 2. Run `ipython notebook`

# %% [markdown]
# ### Let's do some plotting!

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import matplotlib
phi = (1 + np.sqrt(5)) / 2.
matplotlib.rc('figure', figsize=(3,3/phi))

# %%
xs = np.linspace(0, np.pi*2)
ys = np.sin(xs)
plot(xs, ys)
